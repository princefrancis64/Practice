# %%
def outer_fun(a):
    def inner_fun(b):
        return a+b
    return inner_fun

# %%
closure = outer_fun(10)

# %%
closure(5)
# Out:
# 15

# %%
def outer_fun(a):
    print("print the value of a",a)
    def inner_fun(b):
        print("print the value of b",b)
        return a+b
    return inner_fun

# %%
closure = outer_fun(10)
# Out:
# print the value of a 10

# %%
closure
# Out:
# <function __main__.outer_fun.<locals>.inner_fun(b)>

# %%
closure(5)
# Out:
# print the value of b 5
# 15

# %%
closure(99)
# Out:
# print the value of b 99
# 109

# %%
closure(6)
# Out:
# print the value of b 6
# 16

# %%
def outer():
    msg = "hello remember this"
    def inner(name):
        print(msg + name)
    return inner

# %%
out  = outer()

# %%
out("prince")
# Out:
# hello remember thisprince
