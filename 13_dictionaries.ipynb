# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d = {"345":"346464"}

# %%
d
# Out:
# {'345': '346464'}

# %%
d = {"name":"prince","email_id":"prince.francis64@gmail.com","subject":["data science","big data","DSA"]}

# %%
d
# Out:
# {'name': 'prince',
#  'email_id': 'prince.francis64@gmail.com',
#  'subject': ['data science', 'big data', 'DSA']}

# %%
d1 = {"name":"prince"}

# %%
d1 = {45:"prince"}

# %%
d1 = {4654.656:"prince"}

# %%
d1 = {45+65j:"prince"}

# %%
d1 = {(3,4,5):"prince"}

# %%
d1 = {[4,5,6]:"prince"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 d1 = {[4,5,6]:"prince"}
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
d1 = {#$#%:"prince"}
# Out:
#   Cell In[15], line 1
#     d1 = {#$#%:"prince"}
#                         ^
# _IncompleteInputError: incomplete input

# %%
d1 = {"@#@$":"prince"}

# %%
d1
# Out:
# {'@#@$': 'prince'}

# %%
d1 = {"name":"prince","name":"prince"}

# %%
d1
# Out:
# {'name': 'prince'}

# %%
d2 = {"sub":[4,5,7,78,8]}

# %%
d2 = {"sub":23}

# %%
d2 = {"sub":23.54623}

# %%
d2 = {"sub":True}

# %%
d2 = {"sub":23+64j}

# %%
d2 = {"sub":[4,5,6]}

# %%
d2 = {"sub":(4,5,6)}

# %%
d2 = {"sub":{4,5,6,78,8}}

# %%
d2 = {"sub":{"name":"prince"}}

# %%
d
# Out:
# {'name': 'prince',
#  'email_id': 'prince.francis64@gmail.com',
#  'subject': ['data science', 'big data', 'DSA']}

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 d[0]
#
# KeyError: 0

# %%
d["subject"][1]
# Out:
# 'big data'

# %%
d.keys()
# Out:
# dict_keys(['name', 'email_id', 'subject'])

# %%
d.values()
# Out:
# dict_values(['prince', 'prince.francis64@gmail.com', ['data science', 'big data', 'DSA']])

# %%
d.items()
# Out:
# dict_items([('name', 'prince'), ('email_id', 'prince.francis64@gmail.com'), ('subject', ['data science', 'big data', 'DSA'])])

# %%
len(d)
# Out:
# 3

# %%
d["key"] = [4,5,6,7]

# %%
d
# Out:
# {'name': 'prince',
#  'email_id': 'prince.francis64@gmail.com',
#  'subject': ['data science', 'big data', 'DSA'],
#  'key': [4, 5, 6, 7]}

# %%
d["key1"] = [4,5,6,7]

# %%
d
# Out:
# {'name': 'prince',
#  'email_id': 'prince.francis64@gmail.com',
#  'subject': ['data science', 'big data', 'DSA'],
#  'key': [4, 5, 6, 7],
#  'key1': [4, 5, 6, 7]}

# %%
d.update({"key2":(4,5,6,7)})

# %%
d
# Out:
# {'name': 'prince',
#  'email_id': 'prince.francis64@gmail.com',
#  'subject': ['data science', 'big data', 'DSA'],
#  'key': [4, 5, 6, 7],
#  'key1': [4, 5, 6, 7],
#  'key2': (4, 5, 6, 7)}

# %%
d.update({"key2":(4,5,6,7,8)})

# %%
d
# Out:
# {'name': 'prince',
#  'email_id': 'prince.francis64@gmail.com',
#  'subject': ['data science', 'big data', 'DSA'],
#  'key': [4, 5, 6, 7],
#  'key1': [4, 5, 6, 7],
#  'key2': (4, 5, 6, 7, 8)}

# %%
d.pop("key")
# Out:
# [4, 5, 6, 7]

# %%
d
# Out:
# {'name': 'prince',
#  'email_id': 'prince.francis64@gmail.com',
#  'subject': ['data science', 'big data', 'DSA'],
#  'key1': [4, 5, 6, 7],
#  'key2': (4, 5, 6, 7, 8)}

# %%
for i in d.keys():
    print(i,":",d[i])
# Out:
# name : prince
# email_id : prince.francis64@gmail.com
# subject : ['data science', 'big data', 'DSA']
# key1 : [4, 5, 6, 7]
# key2 : (4, 5, 6, 7, 8)
