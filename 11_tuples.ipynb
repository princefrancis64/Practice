# %%
l = [3,4,56,"prince",45+6j,True]

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t = (3,56.67,True,"Prince",45+7j)

# %%
t
# Out:
# (3, 56.67, True, 'Prince', (45+7j))

# %%
t[0]
# Out:
# 3

# %%
t[-1]
# Out:
# (45+7j)

# %%
t[0:3]
# Out:
# (3, 56.67, True)

# %%
t[::-1]
# Out:
# ((45+7j), 'Prince', True, 56.67, 3)

# %%
l
# Out:
# [3, 4, 56, 'prince', (45+6j), True]

# %%
l[0]
# Out:
# 3

# %%
t[0]
# Out:
# 3

# %%
l[0]="prince"

# %%
l[0]
# Out:
# 'prince'

# %%
t[0]="prince"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t[0]="prince"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = 1
b = 2
c = 7

# %%
t = 1,2,7

# %%
t
# Out:
# (1, 2, 7)

# %%
a,b,d  = t

# %%
print(a,b,d)
# Out:
# 1 2 7

# %%
a,b,c = 8,9,5

# %%
for i in t:
    print(i)
# Out:
# 1
# 2
# 7

# %%
t.count(1)
# Out:
# 1

# %%
t.index(2)
# Out:
# 1

# %%
t.index(7)
# Out:
# 2

# %%
t = (2,3,4,5,6,7,2,3,4)

# %%
t.index(2)
# Out:
# 0

# %%
list(t)
# Out:
# [2, 3, 4, 5, 6, 7, 2, 3, 4]

# %%
l
# Out:
# ['prince', 4, 56, 'prince', (45+6j), True]

# %%
tuple(l)
# Out:
# ('prince', 4, 56, 'prince', (45+6j), True)

# %%
t = (3,4,5,(3,4,6),(1,2,3),[1,2,3,4])

# %%
t
# Out:
# (3, 4, 5, (3, 4, 6), (1, 2, 3), [1, 2, 3, 4])

# %%
t[3]
# Out:
# (3, 4, 6)
