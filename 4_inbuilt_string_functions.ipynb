# %%
s  ="prince"

# %%
s.upper()
# Out:
# 'PRINCE'

# %%
s = s.upper()

# %%
s
# Out:
# 'PRINCE'

# %%
s.lower()
# Out:
# 'prince'

# %%
s = "prince francis"

# %%
s.capitalize()
# Out:
# 'Prince francis'

# %%
s.title()
# Out:
# 'Prince Francis'

# %%
s1 = "prince francis"
s1.swapcase()
# Out:
# 'PRINCE FRANCIS'

# %%
s1.casefold()
# Out:
# 'prince francis'

# %%
s = "Teleperformance is my company"

# %%
s.find("my")
# Out:
# 19

# %%
s.find("prince")
# Out:
# -1

# %%
s.index("my")
# Out:
# 19

# %%
s.index("prince")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 s.index("prince")
#
# ValueError: substring not found

# %%
s.count("s")
# Out:
# 1

# %%
s.count("n")
# Out:
# 2

# %%
s.isalpha()
# Out:
# False

# %%
s1 = "prince"

# %%
s1.isalpha()
# Out:
# True

# %%
s1.isalnum()
# Out:
# True

# %%
s.isalnum()
# Out:
# False
