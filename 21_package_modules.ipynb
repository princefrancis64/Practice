# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
import math as m

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------------------ --------------------- 5.8/12.4 MB 37.4 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.4 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 25.1 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------------- -------------------------- 3.4/9.9 MB 27.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 27.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 27.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 27.0 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 6.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 6.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 4.8 MB/s eta 0:00:01
# ...

# %%
from math import sqrt,pi

# %%
sqrt(45)
# Out:
# 6.708203932499369

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import *

# %%
log(4)
# Out:
# 1.3862943611198906

# %%
sqrt(45)
# Out:
# 6.708203932499369

# %%
pi
# Out:
# 3.141592653589793

# %%
## go to the mycalculator folder
