# %%
print(True)
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
True * True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
5>7
# Out:
# False

# %%
2>1
# Out:
# True

# %%
5<3
# Out:
# False

# %%
7<9
# Out:
# True

# %%
4 == 4
# Out:
# True

# %%
5 == 6
# Out:
# False

# %%
(5 ==6 )* 5
# Out:
# 0

# %%
5>=3
# Out:
# True

# %%
3 >=5
# Out:
# False

# %%
6 <= 4
# Out:
# False

# %%
6<=9
# Out:
# True

# %%
#Logical operator
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
5<7 or 5>3
# Out:
# True

# %%
5 == 5 and 6==0
# Out:
# False

# %%
not > and > or

# %%
True or False and False
# Out:
# True

# %%
(True or False) and False
# Out:
# False

# %%
not True or False
# Out:
# False

# %%
not (True or False)
# Out:
# False

# %%
3 + 2 > 4
# Out:
# True

# %%
10 - 5 == 5 and 2*3 ==6
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(56)
# Out:
# True

# %%
bool(-89)
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool("Help")
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool([3,4,5])
# Out:
# True

# %%
bool(())
# Out:
# False

# %%
bool((1,2,3))
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
a = 5
b = a

# %%
id(a)
# Out:
# 140725755487480

# %%
id(b)
# Out:
# 140725755487480

# %%
a is b
# Out:
# True

# %%
x = 6
y = 6

# %%
id(x)
# Out:
# 140725755487512

# %%
id(y)
# Out:
# 140725755487512

# %%
x is y
# Out:
# True

# %%
q = [1,2,3]
v = [1,2,3]

# %%
id(q)
# Out:
# 2042603084928

# %%
id(v)
# Out:
# 2042603078528

# %%
q is v
# Out:
# False

# %%
q is not v
# Out:
# True
