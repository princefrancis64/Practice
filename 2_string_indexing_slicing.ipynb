# %%
s = 'prince'

# %%
s1 = "prince"

# %%
type(s)
# Out:
# str

# %%
type(s1)
# Out:
# str

# %%
s2 = """my name is Prince"""
type(s2)
# Out:
# str

# %%
s3 = "don't"
s3
# Out:
# "don't"

# %%
s2
# Out:
# 'my name is Prince'

# %%
s4 = 'don"t'
s4
# Out:
# 'don"t'

# %%
a = "euron"

# %%
a[0]
# Out:
# 'e'

# %%
a[-1]
# Out:
# 'n'

# %%
a[0:2]
# Out:
# 'eu'

# %%
a[:]
# Out:
# 'euron'

# %%
a[:4]
# Out:
# 'euro'

# %%
a[0:3:2]
# Out:
# 'er'

# %%
a[4:0:-1]
# Out:
# 'noru'

# %%
a[4:-6:-1]
# Out:
# 'norue'

# %%
a[::-1]
# Out:
# 'norue'

# %%
a[:]
# Out:
# 'euron'
