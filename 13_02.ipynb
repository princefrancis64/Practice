# %%
class MyClass:
    x = 5

# %%
p1 = MyClass()
print(p1.x)
# Out:
# 5

# %%
del p1

# %%
p1 = MyClass()
p2 = MyClass()
p3 = MyClass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
class Person:
    pass

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Person("Prince",29)

print(p1.name)
print(p1.age)
# Out:
# Prince
# 29

# %%
class Person:
    pass

# %%
p1 = Person()
p1.name = "Prince"
p1.age = 30

print(p1.name)
print(p1.age)
# Out:
# Prince
# 30

# %%
#setting default values in init method
class Person:
    def __init__(self,name,age=18):
        self.name = name
        self.age = age

p1 = Person("Annies")
p2 = Person("tobias",25)

p1.age
# Out:
# 18

# %%
p2.age
# Out:
# 25

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def greet(self):
        print("Hello,my name is "+self.name)

p1 = Person("Emil",25)
p1.greet()
# Out:
# Hello,my name is Emil

# %%
class Person:
    def __init__(self,name):
        self.name = name

    def printname(self):
        print(self.name)

p1 = Person("Tobias")
p2 = Person("Linus")

p1.printname()
p2.printname()
# Out:
# Tobias
# Linus

# %%
class Person:
    def __init__(myobject,name,age):
        myobject.name = name
        myobject.age = age

    def greet(abc):
        print("Hello my name is " + abc.name)

p1 = Person("emil",36)
p1.greet()
# Out:
# Hello my name is emil

# %%
class Car:
    def __init__(self,brand,model,year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_info(self):
        print(f"{self.year} {self.brand} {self.model}")

car1 = Car("Toyota","Corolla",2020)
car1.display_info()
# Out:
# 2020 Toyota Corolla

# %%
class Person:
    def __init__(self,name):
        self.name = name

    def greet(self):
        return "Hello, "+ self.name


    def welcome(self):
        message = self.greet()
        return message + "! Welcome to our website."


p1 = Person("Tobias")
p1.welcome()
# Out:
# 'Hello, Tobias! Welcome to our website.'

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Person("emil",36)
print(p1.name)
print(p1.age)
# Out:
# emil
# 36

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Person("Tobias",25)
print(p1.age)


p1.age = 26
print(p1.age)
# Out:
# 25
# 26

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Person("linus",30)

del p1.age

print(p1.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       6 p1 = Person("linus",30)
#       8 del p1.age
# ---> 10 print(p1.age)
#
# AttributeError: 'Person' object has no attribute 'age'

# %%
class Person:
    species = "Human"

    def __init__(self,name):
        self.name = name

p1 = Person("Emil")
p2 = Person("Tobias")

print(p1.name)
print(p2.name)
print(p1.species)
print(p2.species)
# Out:
# Emil
# Tobias
# Human
# Human

# %%
class Person:
    lastname = ""

    def __init__(self,name):
        self.name = name

p1 = Person("Linus")
p2 = Person("Emil")

Person.lastname = "Refsnes"

print(p1.lastname)
print(p2.lastname)
# Out:
# Refsnes
# Refsnes

# %%
class Person:
    def __init__(self,name):
        self.name  = name

p1 = Person("Tobias")

p1.age = 25
p1.city = "Osio"

print(p1.name)
print(p1.age)
print(p1.city)
# Out:
# Tobias
# 25
# Osio

# %%
class Calculator:
    def add(self,a,b):
        return a+b
    
    def multiply(self,a,b):
        return a*b
    
calc = Calculator()
print(calc.add(2,3))
print(calc.multiply(2,3))
# Out:
# 5
# 6

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def celebrate_birthday(self):
        self.age+=1
        print(f"Happy birthday! You are now {self.age}")

p1 = Person("Prince",29)
p1.celebrate_birthday()
p1.celebrate_birthday()
# Out:
# Happy birthday! You are now 30
# Happy birthday! You are now 31

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Person("Prince",29)
print(p1)
# Out:
# <__main__.Person object at 0x0000017A08BC4440>

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} {self.age}"

p1 = Person("Prince",29)
print(p1)
# Out:
# Prince 29

# %%
p1

# %%
class Playlist:
    def __init__(self,name):
        self.name = name
        self.songs = []

    def add_song(self,song):
        self.songs.append(song)
        print(f"Added: {song}")

    def remove_song(self,song):
        if song in self.songs:
            self.songs.remove(song)
            print(f"Removed: {song}")

    def show_songs(self):
        print(f"Playlist '{self.name}':")
        for song in self.songs:
            print(f"- {song}")

# %%
my_playlist = Playlist("Favourites")
my_playlist.add_song(["Numb","6-Days"])
my_playlist.show_songs()
# Out:
# Added: ['Numb', '6-Days']
# Playlist 'Favourites':
# - ['Numb', '6-Days']

# %%
my_playlist.songs
# Out:
# [['Numb', '6-Days']]

# %%
class Person:
    def __init__(self,name):
        self.name = name

    def greet(self):
        print("hello!")

p1 = Person("Prince")

del Person.greet

p1.greet()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 12
#       8 p1 = Person("Prince")
#      10 del Person.greet
# ---> 12 p1.greet()
#
# AttributeError: 'Person' object has no attribute 'greet'

# %%
Person.greet()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 Person.greet()
#
# AttributeError: type object 'Person' has no attribute 'greet'

# %%
class Person:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname

    def printname(self):
        print(self.fname,self.lname)

x = Person("John","Doe")
x.printname()
# Out:
# John Doe

# %%
class Student(Person):
    pass

# %%
x = Student("Mike","Olsen")
x.printname()
# Out:
# Mike Olsen

# %%
class Student(Person):
    def __init__(self,fname,lname):
        Person.__init__(self,fname,lname)

# %%
class Student(Person):
    def __init__(self,fname,lname):
        super().__init__(fname,lname)

# %%
class Student(Person):
    def __init__(self,fname,lname):
        super().__init__(fname,lname)
        self.graduationyear = 2019

# %%
c = Student("Michael","Prince")
c.graduationyear
# Out:
# 2019

# %%
class Student(Person):
    def __init__(self,fname,lname,year):
        super().__init__(fname,lname)
        self.graduationyear = year

x = Student("Prince","Francis",2018)

# %%
x.graduationyear
# Out:
# 2018

# %%
class Person:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname

    def welcome(self):
        return f"welcome {self.fname}"

# %%
c = Person("Prince","Francis")
c.welcome()
# Out:
# 'welcome Prince'

# %%
class Student(Person):
    def __init__(self,fname,lname,year):
        super().__init__(fname,lname)
        self.graduationyear = year

    def welcome(self):
        print("Welcome", self.fname, self.lname, "to the class of",self.graduationyear)

d = Student("Prince","Francis",2018)

# %%
d.welcome()
# Out:
# Welcome Prince Francis to the class of 2018

# %%
class Car:
    def __init__(self,brand,model):
        self.brand  = brand
        self.model = model

    def move(self):
        print("Drive!")

class Boat:
    def __init__(self,brand,model):
        self.brand  = brand
        self.model = model

    def move(self):
        print("Sail!")


class Plane:
    def __init__(self,brand,model):
        self.brand  = brand
        self.model = model

    def move(self):
        print("Fly!")


car1 = Car("Ford","Mustang")
boat1 = Boat("Ibiza","Touring 20")
plane1 = Plane("Boeing","747")

for x in (car1,boat1,plane1):
    x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
class Vehicle:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model

    def move(self):
        print("Move!")


class Car(Vehicle):
    pass

class Boat(Vehicle):
    def move(self):
        print("Sail!")


class Plane(Vehicle):
    def move(self):
        print("Fly!")


car1 = Car("Ford","Mustang")
boat1 = Boat("Ibiza","Touring 20")
plane1 = Plane("Boeing","747")


for x in (car1,boat1,plane1):
    x.move()
# Out:
# Move!
# Sail!
# Fly!

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age

p1 = Person('Emil',25)
print(p1.name)
print(p1.__age)
# Out:
# Emil
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 8
#       6 p1 = Person('Emil',25)
#       7 print(p1.name)
# ----> 8 print(p1.__age)
#
# AttributeError: 'Person' object has no attribute '__age'

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age

    def get_age(self):
        return self.__age
    
p1 = Person('Emil',25)
print(p1.get_age())
# Out:
# 25

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age

    def get_age(self):
        return self.__age
    
    def set_age(self,age):
        if age>0:
            self.__age = age
        else:
            print("Age must be positive")

p1 = Person("Tobias",25)
print(p1.get_age())
p1.set_age(26)
print(p1.get_age())
# Out:
# 25
# 26

# %%
class Student:
    def __init__(self,name):
        self.name  = name
        self.__grade = 0

    def set_grade(self,grade):
        if 0<=grade <=100:
            self.__grade = grade
        else:
            print("Grade must be between 0 and 100")

    def get_grade(self):
        return self.__grade
    
    def get_status(self):
        if self.__grade >=60:
            return "Passed"
        else:
            return "Failed"
        
student = Student("Emil")
student.set_grade(85)
print(student.get_grade())
student.get_status()
# Out:
# 85
# 'Passed'

# %%
class Person:
    def __init__(self,name,salary):
        self.name = name
        self._salary = salary


p1 = Person("Linus",5000)
print(p1.name)
print(p1._salary)
# Out:
# Linus
# 5000

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def __validate(self,num):
        if not isinstance(num,(int,float)):
            return False
        return True
    
    def add(self,num):
        if self.__validate(num):
            self.result += num
        else:
            print("Invalid Number")

calc = Calculator()
calc.add(10)
calc.add(5)
print(calc.result)
# Out:
# 15

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.__age = age

p1 = Person("Prince",29)

print(p1._Person__age)
# Out:
# 29
