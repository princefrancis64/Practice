# %%
def add(a,b):
    return a+b

# %%
add(5,6)
# Out:
# 11

# %%
def add(*args):
    print(args)

# %%
add(1,2,3,4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
add(4,5,6,7,7,8,9,0)
# Out:
# (4, 5, 6, 7, 7, 8, 9, 0)

# %%
def add(*prince):
    print(prince)

# %%
add(1,2,3,4,5,56,7,8,"ljlj")
# Out:
# (1, 2, 3, 4, 5, 56, 7, 8, 'ljlj')

# %%
def add(*prince):
    print(prince)
    j = 0
    for i in prince:
        j = j+i
    return j

# %%
add()
# Out:
# ()
# 0

# %%
add(4,6,7,8,8)
# Out:
# (4, 6, 7, 8, 8)
# 33

# %%
add(10,15)
# Out:
# (10, 15)
# 25

# %%
def multiply_all(factor,*prince):
    return factor,prince

# %%
multiply_all(1,(3,4,5))
# Out:
# (1, ((3, 4, 5),))

# %%
multiply_all(1)
# Out:
# (1, ())

# %%
multiply_all(0,3,4,5,5)
# Out:
# (0, (3, 4, 5, 5))

# %%
def multiply_all(factor,*prince):
    return factor*prince

# %%
multiply_all(2,1,4,5)
# Out:
# (1, 4, 5, 1, 4, 5)

# %%
def profile(**kwargs):
    print(kwargs)

# %%
profile()
# Out:
# {}

# %%
type(profile())
# Out:
# {}
# NoneType

# %%
profile("prince")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 profile("prince")
#
# TypeError: profile() takes 0 positional arguments but 1 was given

# %%
profile("prince","francis")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 profile("prince","francis")
#
# TypeError: profile() takes 0 positional arguments but 2 were given

# %%
profile(name = "prince",surname = "francis")
# Out:
# {'name': 'prince', 'surname': 'francis'}

# %%
def profile(**kwargs):
    for i in kwargs.items():
        print(i)

# %%
profile(name = "prince",surname = "francis")
# Out:
# ('name', 'prince')
# ('surname', 'francis')

# %%
def profile(company,**kwargs):
    for i in kwargs.items():
        print(i,company)

# %%
profile("euron")

# %%
profile("profile",name = "prince",surname = "francis")
# Out:
# ('name', 'prince') profile
# ('surname', 'francis') profile

# %%
def mix_fun(*prince,**francis):
    return prince,francis

# %%
mix_fun()
# Out:
# ((), {})

# %%
mix_fun(4,5,6,7,"prince",name = "prince",age = 345)
# Out:
# ((4, 5, 6, 7, 'prince'), {'name': 'prince', 'age': 345})

# %%
mix_fun(4,5,6,7,"prince",name = "prince",age = 345,4,8,9)
# Out:
#   Cell In[5], line 1
#     mix_fun(4,5,6,7,"prince",name = "prince",age = 345,4,8,9)
#                                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
def great(name,/):
    print(f"you are great {name}")

# %%
great("Prince")
# Out:
# you are great Prince

# %%
great(name = "prince")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 great(name = "prince")
#
# TypeError: great() got some positional-only arguments passed as keyword arguments: 'name'

# %%
def great(name):
    print(f"you are great {name}")

# %%
great(name = "prince")
# Out:
# you are great prince

# %%
def add(a,b,c):
    return a+b+c

# %%
add(4,5,6)
# Out:
# 15

# %%
add(b = 45,a = 3,c= 1)
# Out:
# 49

# %%
def add(a,b,c,/):
    return a+b+c

# %%
add(b = 45,a = 3,c= 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 add(b = 45,a = 3,c= 1)
#
# TypeError: add() got some positional-only arguments passed as keyword arguments: 'a, b, c'

# %%
def add(a,b,/,c):
    return a+b+c

# %%
add(a = 45,b = 3,c= 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 add(a = 45,b = 3,c= 1)
#
# TypeError: add() got some positional-only arguments passed as keyword arguments: 'a, b'

# %%
def add(a,b,*,c):
    return a+b+c

# %%
add(4,5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 add(4,5,6)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
add(a = 1,b=2,c=3)
# Out:
# 6
