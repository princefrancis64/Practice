# %%
s = "prince"

# %%
id(s)
# Out:
# 2398675925488

# %%
modify = s+"francis"

# %%
id(modify)
# Out:
# 2398676183344

# %%
s = s+"francis"

# %%
id(s)
# Out:
# 2398676537968

# %%
s = "euron"

# %%
s[0] = "p"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 s[0] = "p"
#
# TypeError: 'str' object does not support item assignment

# %%
a = "euron"
b = "euron"

# %%
id(a)
# Out:
# 2398676373008

# %%
id(b)
# Out:
# 2398676373008

# %%
c = "prin" + "ce"

# %%
d = "prince"

# %%
id(c)
# Out:
# 2398676464480

# %%
id(d)
# Out:
# 2398676464480
