# %%
print("my name is Prince. I used to teach data")
# Out:
# my name is Prince. I used to teach data

# %%
print("my name is Prince .\n I used to teach data.")
# Out:
# my name is Prince .
#  I used to teach data.

# %%
print("my name is Prince \t I used to teach data.")
# Out:
# my name is Prince 	 I used to teach data.

# %%
print("\\")
# Out:
# \

# %%
raw_data = r"C:\Users\Prince\Desktop\python"
print(raw_data)
# Out:
# C:\Users\Prince\Desktop\python

# %%
raw_data = "C:\\Users\\Prince\\Desktop\\python"
print(raw_data)
# Out:
# C:\Users\Prince\Desktop\python

# %%
print("\U0001F600")
# Out:
# 😀

# %%
print("\u00A9")
# Out:
# ©

# %%
print("\N{GREEK CAPITAL LETTER DELTA}")
# Out:
# Δ

# %%
print("\N{SNOWMAN}")
# Out:
# ☃

# %%
"""my name is Prince
I am working in teleperformance
I used to teach data"""
# Out:
# 'my name is Prince\nI am working in teleperformance\nI used to teach data'

# %%
"my name is Prince"\
"I am working in teleperformance"\
"I used to teach data"
# Out:
# 'my name is PrinceI am working in teleperformanceI used to teach data'

# %%
name = "Prince"
age = 29
phone = 123456789

print("my name is Prince, my age is 29 and my phone number is 123456789")
# Out:
# my name is Prince, my age is 29 and my phone number is 123456789

# %%
name = "Prince"
age = 29
phone = 123456789

print(f"my name is {name}, my age is {age} and my phone number is {phone}")
# Out:
# my name is Prince, my age is 29 and my phone number is 123456789

# %%
name = input("enter your name")

# %%
name
# Out:
# 'Prince'

# %%
age = input("enter your age")

# %%
age
# Out:
# '29'

# %%
type(age)
# Out:
# str

# %%
name  = int(input("enter your age"))

# %%
name = "Prince"

# %%
print("my name is {} my age is {} and my phone number is {}".format(name,age,phone))
# Out:
# my name is 29 my age is 29 and my phone number is 123456789

# %%
print("my name is {n} my age is {a}".format(a = name,n = age))
# Out:
# my name is 29 my age is 29

# %%
from string import Template

# %%
Template("my name is $name my age is $age").substitute(name = name,age=age)
# Out:
# 'my name is Prince my age is 29'

# %%
email_template = Template(""" 
                          From : $sender
                          To : $receiver
                          Subject : $subject
                          $body
                        """)

# %%
email_template.substitute(sender = "prince.francis64@gmail.com",receiver = "francis@fd@gmail.com",subject = "test",body = "this is a test email")
# Out:
# ' \n                          From : prince.francis64@gmail.com\n                          To : francis@fd@gmail.com\n                          Subject : test\n                          this is a test email\n                        '
