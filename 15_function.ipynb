# %%
l = [3,4,5,6,7,8]

# %%
l1=  []
for i in l:
    if i%2==0:
        print(i)
        l1.append(i)
# Out:
# 4
# 6
# 8

# %%
l1
# Out:
# [4, 6, 8]

# %%
len(l)
# Out:
# 6

# %%
type(l)
# Out:
# list

# %%
def test():
    pass

# %%
test()

# %%
def test1():
    print("my name is Prince Francis")

# %%
test1()
# Out:
# my name is Prince Francis

# %%
a = test1()
a
# Out:
# my name is Prince Francis

# %%
a + "euron"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a + "euron"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(test1())
# Out:
# my name is Prince Francis
# NoneType

# %%
a

# %%
def test2():
    return "my name is Prince Francis"

# %%
test2()
# Out:
# 'my name is Prince Francis'

# %%
type(test2())
# Out:
# str

# %%
test2() + " euron"
# Out:
# 'my name is Prince Francis euron'

# %%
def test3():
    return "prince",45,234.56

# %%
test3()
# Out:
# ('prince', 45, 234.56)

# %%
type(test3())
# Out:
# tuple

# %%
a,b,c = test3()

# %%
a
# Out:
# 'prince'

# %%
b
# Out:
# 45

# %%
c
# Out:
# 234.56

# %%
def test4(a,b):
    return a,b

# %%
test4(b = 4,a = 5)
# Out:
# (5, 4)

# %%
test4("prince",4654654)
# Out:
# ('prince', 4654654)

# %%
def add(a,b):
    return a+b

# %%
add(4,5)
# Out:
# 9

# %%
def sub(a,b):
    return a-b

# %%
sub(6567,646543)
# Out:
# -639976

# %%
def is_even(a):
    return a%2==0

# %%
is_even(4)
# Out:
# True

# %%
is_even(5)
# Out:
# False

# %%
def power(x,y):
    return x**y

# %%
power(2,3)
# Out:
# 8

# %%
def average(a,b,c):
    return (a+b+c)/3

# %%
average(1,2,3)
# Out:
# 2.0

# %%
average(4,5,6)
# Out:
# 5.0

# %%
average(4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 average(4,5)
#
# TypeError: average() missing 1 required positional argument: 'c'

# %%
def average2(a,b,c=0):
    return (a+b+c)/3

# %%
average2(4,5)
# Out:
# 3.0

# %%
average(4,5,6)
# Out:
# 5.0

# %%
def course_discount(price,discount= 100):
    return price-discount

# %%
course_discount(1000,80)
# Out:
# 920

# %%
course_discount(3499,500)
# Out:
# 2999

# %%
def course_discount2(price: int,discount:int=100)->int:
    return price  -  discount

# %%
course_discount2(500,99)
# Out:
# 401

# %%
def add(a:int,b:int)->str:
    """Adding 2 numbers"""
    return a+b

# %%
add("prince"," francis")
# Out:
# 'prince francis'

# %%
add(3,4)
# Out:
# 7

# %%
def add(a,b):
    """
    This function is created by Prince Francis
    and this function will take input of two integers and give you an
    output of its data
    """
    return a+b

# %%
add(4,5)
# Out:
# 9
