# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s = {34}

# %%
type(s)
# Out:
# set

# %%
s = {3,4,5,6,7,8,7,6,5,4,3,4,5,6,67,"prince","prince","Prince"}

# %%
s
# Out:
# {3, 4, 5, 6, 67, 7, 8, 'Prince', 'prince'}

# %%
s1 = {45,56,56,45.67,"prince","francis",True}

# %%
s1
# Out:
# {45, 45.67, 56, True, 'francis', 'prince'}

# %%
s2 = {(4,5,6,7)}

# %%
s2
# Out:
# {(4, 5, 6, 7)}

# %%
s3 = {[1,2,3,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s3 = {[1,2,3,4]}
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
s4  = {5,6,7,{343,2}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s4  = {5,6,7,{343,2}}
#
# TypeError: cannot use 'set' as a set element (unhashable type: 'set')

# %%
s5 = {4,5,6,87,8,2,3,4,5,6,7,8,9}

# %%
s5
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 87}

# %%
s6 = {546,5436,456,23,55,645,464,75576,232,67,45,3234,234,2,232.5}

# %%
s6
# Out:
# {2, 23, 45, 55, 67, 232, 232.5, 234, 456, 464, 546, 645, 3234, 5436, 75576}

# %%
s7={3,2,1}

# %%
s7
# Out:
# {1, 2, 3}

# %%
s8 = {"prince",44,121,6,1,3,87}

# %%
s8
# Out:
# {1, 121, 3, 44, 6, 87, 'prince'}

# %%
set()
# Out:
# set()

# %%
s2
# Out:
# {(4, 5, 6, 7)}

# %%
s2.add(4)

# %%
s2
# Out:
# {(4, 5, 6, 7), 4}

# %%
s2.add("prince")

# %%
s2
# Out:
# {(4, 5, 6, 7), 4, 'prince'}

# %%
s2.update([3,4])

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 4, 'prince'}

# %%
s2.update([3,4,[4,5]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 s2.update([3,4,[4,5]])
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 4, 'prince'}

# %%
s2.remove(56)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s2.remove(56)
#
# KeyError: 56

# %%
s2.remove(4)

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 'prince'}

# %%
s2.discard(56)

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 'prince'}

# %%
s2.pop(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 s2.pop(4)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s2.pop
# Out:
# <function set.pop()>

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 'prince'}

# %%
s2.pop()
# Out:
# (4, 5, 6, 7)

# %%
s2
# Out:
# {3, 'prince'}

# %%
s2
# Out:
# {3, 'prince'}

# %%
s2.pop()
# Out:
# 3

# %%
s2
# Out:
# {'prince'}

# %%
s2.clear()

# %%
s2
# Out:
# set()

# %%
s5
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 87}

# %%
s8 = s5.copy()#shallow copy

# %%
s8
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 87}

# %%
len(s8)
# Out:
# 9

# %%
5 in s8
# Out:
# True

# %%
456 in s8
# Out:
# False

# %%
345 not in s8
# Out:
# True

# %%
s1 = {4,5,6}
s2 = {5,6,7}

# %%
s1.union(s2)
# Out:
# {4, 5, 6, 7}

# %%
s1.intersection(s2)
# Out:
# {5, 6}

# %%
s1.difference(s2)
# Out:
# {4}

# %%
s2.difference(s1)
# Out:
# {7}

# %%
a = {1,2}
b = {1,2,3}

# %%
a.issubset(a)
# Out:
# True

# %%
b.issubset(a)
# Out:
# False

# %%
f = frozenset([3,4,5,67,5,4,5,6,7])

# %%
f
# Out:
# frozenset({3, 4, 5, 6, 7, 67})

# %%
f[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 f[0] = 1
#
# TypeError: 'frozenset' object does not support item assignment

# %%
s2
# Out:
# {5, 6, 7}

# %%
s2[0] = "prince"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 s2[0] = "prince"
#
# TypeError: 'set' object does not support item assignment
