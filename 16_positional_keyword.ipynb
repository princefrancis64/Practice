# %%
def add(a,b):
    return a+b

# %%
add(34,98)
# Out:
# 132

# %%
add(b = 46,a =1)
# Out:
# 47

# %%
def registration(name,mail_id,phone):
    print(name)
    print(mail_id)
    print(phone)

# %%
registration("prince","prince.francis64@gmail.com",654646)
# Out:
# prince
# prince.francis64@gmail.com
# 654646

# %%
registration(phone=64648,name = "francis",mail_id="francis.fd@gmail.com")
# Out:
# francis
# francis.fd@gmail.com
# 64648

# %%
def registration(name,mail_id,phone_no,batch="python"):
    return name,mail_id,phone_no,batch

# %%
registration(name = "prince",mail_id="prince.francis64@gmail.com",phone_no=6646446,batch="python with DSA")
# Out:
# ('prince', 'prince.francis64@gmail.com', 6646446, 'python with DSA')
