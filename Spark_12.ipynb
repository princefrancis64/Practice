# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").appName("test").getOrCreate()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2dde34aa-712b-43e0-9c1f-a15b01c84ea7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2dde34aa-712b-43e0-9c1f-a15b01c84ea7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
orders_df = spark.read.format("csv").option("header","true").option("inferSchema","true").load("orders_2.txt")

# %%
orders_df.show()
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# ...

# %%
#shortcut methods
spark.read.csv("orders_2.txt",header="true",inferSchema = "true").show()
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# ...

# %%
orders_df_json = spark.read.json("orders.json")

# %%
orders_df_json.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
#Other method
spark.read.format("json").load("orders.json").show()
# Out:
# +-----------+--------------------+--------+---------------+
# |customer_id|          order_date|order_id|   order_status|
# +-----------+--------------------+--------+---------------+
# |      11599|2013-07-25 00:00:...|       1|         CLOSED|
# |        256|2013-07-25 00:00:...|       2|PENDING_PAYMENT|
# |      12111|2013-07-25 00:00:...|       3|       COMPLETE|
# |       8827|2013-07-25 00:00:...|       4|         CLOSED|
# |      11318|2013-07-25 00:00:...|       5|       COMPLETE|
# |       7130|2013-07-25 00:00:...|       6|       COMPLETE|
# |       4530|2013-07-25 00:00:...|       7|       COMPLETE|
# |       2911|2013-07-25 00:00:...|       8|     PROCESSING|
# |       5657|2013-07-25 00:00:...|       9|PENDING_PAYMENT|
# |       5648|2013-07-25 00:00:...|      10|PENDING_PAYMENT|
# |        918|2013-07-25 00:00:...|      11| PAYMENT_REVIEW|
# |       1837|2013-07-25 00:00:...|      12|         CLOSED|
# |       9149|2013-07-25 00:00:...|      13|PENDING_PAYMENT|
# ...

# %%
orders_df_parquet = spark.read.parquet("orders_parquet")

# %%
orders_df_parquet.show()
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# ...

# %%
#orders_parquet = spark.read.csv(
#     "orders_2.txt",
#     header=True,
#     inferSchema=True
# )

# %%
#orders_parquet.write.parquet("orders_parquet")

# %%
orders_df_parquet.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: timestamp (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
orders_df.write.orc("orders_orc")

# %%
orders_df_orc = spark.read.orc("orders_orc")

# %%
orders_df_orc.show()
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# ...

# %%
filtered_df =  orders_df.where("customer_id = 11599")

# %%
filtered_df.show(truncate = False)
# Out:
# +--------+-------------------+-----------+------------+
# |order_id|order_date         |customer_id|order_status|
# +--------+-------------------+-----------+------------+
# |1       |2013-07-25 00:00:00|11599      |CLOSED      |
# |11397   |2013-10-03 00:00:00|11599      |COMPLETE    |
# |23908   |2013-12-20 00:00:00|11599      |COMPLETE    |
# |53545   |2014-06-27 00:00:00|11599      |PENDING     |
# |59911   |2013-10-17 00:00:00|11599      |PROCESSING  |
# +--------+-------------------+-----------+------------+

# %%
# We can also use filter
orders_df.filter("customer_id = 11599").show()
# Out:
# +--------+-------------------+-----------+------------+
# |order_id|         order_date|customer_id|order_status|
# +--------+-------------------+-----------+------------+
# |       1|2013-07-25 00:00:00|      11599|      CLOSED|
# |   11397|2013-10-03 00:00:00|      11599|    COMPLETE|
# |   23908|2013-12-20 00:00:00|      11599|    COMPLETE|
# |   53545|2014-06-27 00:00:00|      11599|     PENDING|
# |   59911|2013-10-17 00:00:00|      11599|  PROCESSING|
# +--------+-------------------+-----------+------------+

# %%
orders_df.createOrReplaceTempView("orders")

# %%
filtered_df = spark.sql("select * from orders where order_status = 'CLOSED'")

# %%
filtered_df.show()
# Out:
# +--------+-------------------+-----------+------------+
# |order_id|         order_date|customer_id|order_status|
# +--------+-------------------+-----------+------------+
# |       1|2013-07-25 00:00:00|      11599|      CLOSED|
# |       4|2013-07-25 00:00:00|       8827|      CLOSED|
# |      12|2013-07-25 00:00:00|       1837|      CLOSED|
# |      18|2013-07-25 00:00:00|       1205|      CLOSED|
# |      24|2013-07-25 00:00:00|      11441|      CLOSED|
# |      25|2013-07-25 00:00:00|       9503|      CLOSED|
# |      37|2013-07-25 00:00:00|       5863|      CLOSED|
# |      51|2013-07-25 00:00:00|      12271|      CLOSED|
# |      57|2013-07-25 00:00:00|       7073|      CLOSED|
# |      61|2013-07-25 00:00:00|       4791|      CLOSED|
# |      62|2013-07-25 00:00:00|       9111|      CLOSED|
# |      87|2013-07-25 00:00:00|       3065|      CLOSED|
# |      90|2013-07-25 00:00:00|       9131|      CLOSED|
# |     101|2013-07-25 00:00:00|       5116|      CLOSED|
# ...

# %%
#convert a table to a dataframe
orders_df = spark.read.table("orders")

# %%
orders_df.show()
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|         order_date|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       1|2013-07-25 00:00:00|      11599|         CLOSED|
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# ...

# %%
#try out these
orders_df.createOrReplaceGlobalTempView("orders")
orders_df.createTempView("orders")
