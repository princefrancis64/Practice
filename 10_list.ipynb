# %%
l= []

# %%
type(l)
# Out:
# list

# %%
l  =[3,4,5,6,7,7]

# %%
l
# Out:
# [3, 4, 5, 6, 7, 7]

# %%
l1 = [4,56.56,True,45+8j,"prince"]

# %%
l1[0]
# Out:
# 4

# %%
l1[-1]
# Out:
# 'prince'

# %%
l1
# Out:
# [4, 56.56, True, (45+8j), 'prince']

# %%
l1[0:3]
# Out:
# [4, 56.56, True]

# %%
l1[::-1]
# Out:
# ['prince', (45+8j), True, 56.56, 4]

# %%
l1[4]
# Out:
# 'prince'

# %%
l1[4][0]
# Out:
# 'p'

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list("prince")
# Out:
# ['p', 'r', 'i', 'n', 'c', 'e']

# %%
l1.append(3)

# %%
l1
# Out:
# [4, 56.56, True, (45+8j), 'prince', 3]

# %%
l1.append([1,2,3,4,5])

# %%
l1
# Out:
# [4, 56.56, True, (45+8j), 'prince', 3, [1, 2, 3, 4, 5]]

# %%
l1.extend([1,2])

# %%
l1
# Out:
# [4, 56.56, True, (45+8j), 'prince', 3, [1, 2, 3, 4, 5], 1, 2]

# %%
l1.append(345)

# %%
l1
# Out:
# [4, 56.56, True, (45+8j), 'prince', 3, [1, 2, 3, 4, 5], 1, 2, 345]

# %%
l1.insert(3,45)

# %%
l1
# Out:
# [4, 56.56, True, 45, (45+8j), 'prince', 3, [1, 2, 3, 4, 5], 1, 2, 345]

# %%
l1.insert(100,464)

# %%
l1
# Out:
# [4, 56.56, True, 45, (45+8j), 'prince', 3, [1, 2, 3, 4, 5], 1, 2, 345, 464]

# %%
l1.remove(1)

# %%
l1
# Out:
# [4, 56.56, 45, (45+8j), 'prince', 3, [1, 2, 3, 4, 5], 1, 2, 345, 464]

# %%
l1.remove("prince")

# %%
l1
# Out:
# [4, 56.56, 45, (45+8j), 3, [1, 2, 3, 4, 5], 1, 2, 345, 464]

# %%
l1.pop()
# Out:
# 464

# %%
l1
# Out:
# [4, 56.56, 45, (45+8j), 3, [1, 2, 3, 4, 5], 1, 2, 345]

# %%
l1.pop(3)
# Out:
# (45+8j)

# %%
l1
# Out:
# [4, 56.56, 45, 3, [1, 2, 3, 4, 5], 1, 2, 345]

# %%
l1.index(1)
# Out:
# 5

# %%
l1.append(1)

# %%
l1
# Out:
# [4, 56.56, 45, 3, [1, 2, 3, 4, 5], 1, 2, 345, 1]

# %%
l1.index(1)
# Out:
# 5

# %%
l1
# Out:
# [4, 56.56, 45, 3, [1, 2, 3, 4, 5], 1, 2, 345, 1, 1]

# %%
l1.count(1)
# Out:
# 3

# %%
l1.reverse()

# %%
l1
# Out:
# [1, 1, 345, 2, 1, [1, 2, 3, 4, 5], 3, 45, 56.56, 4]

# %%
l1[::-1]
# Out:
# [4, 56.56, 45, 3, [1, 2, 3, 4, 5], 1, 2, 345, 1, 1]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
l = [3,4,5,6]

# %%
l1 = l

# %%
l1
# Out:
# [3, 4, 5, 6]

# %%
id(l)
# Out:
# 2860392410624

# %%
id(l1)
# Out:
# 2860392410624

# %%
l2 = l.copy()

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
id(l2)
# Out:
# 2860392411648

# %%
l[0] = "prince"

# %%
l
# Out:
# ['prince', 4, 5, 6]

# %%
l1
# Out:
# ['prince', 4, 5, 6]

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
6 in l1
# Out:
# True

# %%
l1 * 4
# Out:
# ['prince', 4, 5, 6, 'prince', 4, 5, 6, 'prince', 4, 5, 6, 'prince', 4, 5, 6]

# %%
l1
# Out:
# ['prince', 4, 5, 6]

# %%
l1 + l2
# Out:
# ['prince', 4, 5, 6, 3, 4, 5, 6]

# %%
l1 + "prince"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 l1 + "prince"
#
# TypeError: can only concatenate list (not "str") to list

# %%
l = ["prince","francis"]

# %%
" ".join(l)
# Out:
# 'prince francis'

# %%
s = "prince"

# %%
s.split("i")
# Out:
# ['pr', 'nce']

# %%
l = [5,6,7,[4,5,6,"prince"],[5,6,7,8]]

# %%
l
# Out:
# [5, 6, 7, [4, 5, 6, 'prince'], [5, 6, 7, 8]]

# %%
l[4]
# Out:
# [5, 6, 7, 8]

# %%
l[4][2]
# Out:
# 7

# %%
for i in l:
    print(i)
# Out:
# 5
# 6
# 7
# [4, 5, 6, 'prince']
# [5, 6, 7, 8]

# %%
type(l)
# Out:
# list

# %%
for i in l:
    if type(i)==list:
        print(i)
# Out:
# [4, 5, 6, 'prince']
# [5, 6, 7, 8]

# %%
len(l)
# Out:
# 5

# %%
l = [5,6,7,8,9,9]

# %%
max(l)
# Out:
# 9

# %%
min(l)
# Out:
# 5
